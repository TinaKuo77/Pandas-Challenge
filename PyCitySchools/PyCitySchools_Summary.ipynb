# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="outer", on=["school_name"])
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
#Calculate the total number of schools
total_number_schools = len(school_data_complete["School ID"].unique())
print(f"The Total Number of Schools is {round(total_number_schools,2)}")
# Out:
# The Total Number of Schools is 15

# %%
#Calculate the total number of students
total_number_students = len(school_data_complete["Student ID"].unique())
print(f"The Total Number of Students is {round(total_number_students,2)}")
# Out:
# The Total Number of Students is 39170

# %%
#Calculate the total budget
total_budget = school_data["budget"].sum()
print(f"The Total Budget is {round(total_budget,2)}")
# Out:
# The Total Budget is 24649428

# %%
#Calculate the average math score
average_math_score = student_data["math_score"].mean()
print(f"The average Math Score is {round(average_math_score,2)}")
# Out:
# The average Math Score is 78.99

# %%
#Calculate the average reading score
average_reading_score = student_data["reading_score"].mean()
print(f"The average Reading Score is {round(average_reading_score,2)}")
# Out:
# The average Reading Score is 81.88

# %%
#Calculate the percentage of students with a passing math score (70 or greater)
student_data["#passing_math"] = student_data["math_score"] >= 70
percent_passing_math = ((student_data["#passing_math"]).mean())*100
print(f"The percentage of students with a passing math score (70 or greater) is {round(percent_passing_math,2)} % ")
# Out:
# The percentage of students with a passing math score (70 or greater) is 74.98 %

# %%
#Calculate the percentage of students with a passing reading score (70 or greater)
student_data["#passing_reading"] = student_data["reading_score"] >= 70
percent_passing_reading = ((student_data["#passing_reading"]).mean())*100
print(f"The percentage of students with a passing reading score (70 or greater) is {round(percent_passing_reading,2)} % ")
# Out:
# The percentage of students with a passing reading score (70 or greater) is 85.81 %

# %%
#Calculate the percentage of students who passed math and reading (% Overall Passing)
overall_passing = (percent_passing_math + percent_passing_reading)/2
print(f"The percentage of students who passed math and reading is {round(overall_passing,2)} % ")
# Out:
# The percentage of students who passed math and reading is 80.39 %

# %%
#Create a dataframe to hold the above results
#Optional: give the displayed data cleaner formatting
district_results = [{"Total Schools": total_number_schools, 
            "Total Students": total_number_students, 
            "Total Budget": total_budget, 
            "Average Math Score":  round(average_math_score,2), 
            "Average Reading Score":  round(average_reading_score,2), 
           "Passing Math (%)": round(percent_passing_math,2),
           "Passing Reading (%)": round(percent_passing_reading,2),
            "Overall Passing Rate (%)": round(overall_passing,2)}]
Summary_table = pd.DataFrame(district_results)

#Formatting
Summary_table["Total Students"] = Summary_table["Total Students"].map("{:,.0f}".format)
Summary_table["Total Budget"] = Summary_table["Total Budget"].astype(float).map("${:,.2f}".format)
Summary_table["Passing Math (%)"] = Summary_table["Passing Math (%)"].map("{:.2f}%".format)
Summary_table["Passing Reading (%)"] = Summary_table["Passing Reading (%)"].map("{:.2f}%".format)
Summary_table["Overall Passing Rate (%)"] = Summary_table["Overall Passing Rate (%)"].map("{:.2f}%".format)

Summary_table
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00               78.99
#
#    Average Reading Score Passing Math (%) Passing Reading (%)  \
# 0                  81.88           74.98%              85.81%
#
#   Overall Passing Rate (%)
# 0                   80.39%

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
#Group by School Name

grouped_school_data_complete = school_data_complete.groupby(['school_name'])
school_typ = []
total_students = []
total_budgets = []
per_studnet_budgets = []
average_math = []
average_Reading = []
number_pass_math = []
percent_pass_math = []
percent_pass_reading = []
percent_overall_pass = []

school_type = grouped_school_data_complete["type"].unique().str[0]
#school_type

# %%
# total students of each schools
total_students = grouped_school_data_complete["school_name"].count()
#total_students

# %%
# total bugets of each schools
total_budgets = grouped_school_data_complete["budget"].unique()
#total_budgets

# %%
# Per Student budget of each schools
per_studnet_budgets = total_budgets/total_students
#per_studnet_budgets

# %%
#Average Math Score of each schools
average_math = grouped_school_data_complete['math_score'].mean()
#average_math

# %%
#Average Reading Score of each schools
average_Reading = grouped_school_data_complete['reading_score'].mean()
#average_Reading

# %%
# % Passing Math (The percentage of students that passed math.
# A table for students with a passing math score (70 or greater) and a passing reading score (70 or greater)

school_data_complete["passing_math"] = school_data_complete["math_score"] >= 70
school_data_complete["passing_reading"] = school_data_complete["reading_score"] >= 70

# %%
#drop math_fail
number_pass_math = school_data_complete[school_data_complete['math_score']>=70].groupby('school_name')['math_score'].count()
#number_pass_math

percent_pass_math = (number_pass_math/ total_students) *100
#percent_pass_math

# %%
# % Passing Reading (The percentage of students that passed reading.)
#drop reading_fail
number_pass_reading = school_data_complete[school_data_complete['reading_score']>=70].groupby('school_name')['reading_score'].count()

#Passing Reading percentage
percent_pass_reading = (number_pass_reading / total_students) *100
#percent_pass_reading

# %%
# % Overall Passing (The percentage of students that passed math and reading.)
percent_overall_pass = (percent_pass_reading + percent_pass_math)/2
#percent_overall_pass

# %%
# Create a dataframe to hold the above results

for school in grouped_school_data_complete: 
    Summary_table = pd.DataFrame( {"School Type": school_type, 
            "Total Students": total_students, 
            "Total Budget": total_budgets, 
            "Per Student Budget": per_studnet_budgets, 
            "Average Math Score":  round(average_math,2), 
            "Average Reading Score":  round(average_Reading,2), 
           "Passing Math (%)": round(percent_pass_math,2),
           "Passing Reading (%)": round(percent_pass_reading,2),
            "Overall Passing Rate (%)": round(percent_overall_pass,2)})
    
#Formatting
Summary_table["Total Students"] = Summary_table["Total Students"].map("{:,.0f}".format)
Summary_table["Total Budget"] = Summary_table["Total Budget"].astype(float).map("${:,.2f}".format)
Summary_table["Per Student Budget"] = Summary_table["Per Student Budget"].astype(float).map("${:,.2f}".format)
Summary_table["Passing Math (%)"] = Summary_table["Passing Math (%)"].map("{:.2f}%".format)
Summary_table["Passing Reading (%)"] = Summary_table["Passing Reading (%)"].map("{:.2f}%".format)
Summary_table["Overall Passing Rate (%)"] = Summary_table["Overall Passing Rate (%)"].map("{:.2f}%".format)

Summary_table
# Out:
#                       School Type Total Students   Total Budget  \
# school_name
# Bailey High School       District          4,976  $3,124,928.00
# Cabrera High School       Charter          1,858  $1,081,356.00
# Figueroa High School     District          2,949  $1,884,411.00
# Ford High School         District          2,739  $1,763,916.00
# Griffin High School       Charter          1,468    $917,500.00
# Hernandez High School    District          4,635  $3,022,020.00
# Holden High School        Charter            427    $248,087.00
# Huang High School        District          2,917  $1,910,635.00
# Johnson High School      District          4,761  $3,094,650.00
# Pena High School          Charter            962    $585,858.00
# Rodriguez High School    District          3,999  $2,547,363.00
# Shelton High School       Charter          1,761  $1,056,600.00
# Thomas High School        Charter          1,635  $1,043,130.00
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
# Top Performing Schools (By % Overall Passing)
top_five_summary = Summary_table.sort_values(["Overall Passing Rate (%)"], ascending=False)
top_five_summary.head(5)
# Out:
#                     School Type Total Students   Total Budget  \
# school_name
# Cabrera High School     Charter          1,858  $1,081,356.00
# Thomas High School      Charter          1,635  $1,043,130.00
# Griffin High School     Charter          1,468    $917,500.00
# Pena High School        Charter            962    $585,858.00
# Wilson High School      Charter          2,283  $1,319,574.00
#
#                     Per Student Budget  Average Math Score  \
# school_name
# Cabrera High School            $582.00               83.06
# Thomas High School             $638.00               83.42
# Griffin High School            $625.00               83.35
# Pena High School               $609.00               83.84
# Wilson High School             $578.00               83.27
#
#                      Average Reading Score Passing Math (%)  \
# school_name
# Cabrera High School                  83.98           94.13%
# Thomas High School                   83.85           93.27%
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
#Bottom Performing Schools (By % Overall Passing)
Bottom_five_summary = Summary_table.sort_values(["Overall Passing Rate (%)"], ascending=True)
Bottom_five_summary.head(5)
# Out:
#                       School Type Total Students   Total Budget  \
# school_name
# Rodriguez High School    District          3,999  $2,547,363.00
# Figueroa High School     District          2,949  $1,884,411.00
# Huang High School        District          2,917  $1,910,635.00
# Johnson High School      District          4,761  $3,094,650.00
# Ford High School         District          2,739  $1,763,916.00
#
#                       Per Student Budget  Average Math Score  \
# school_name
# Rodriguez High School            $637.00               76.84
# Figueroa High School             $639.00               76.71
# Huang High School                $655.00               76.63
# Johnson High School              $650.00               77.07
# Ford High School                 $644.00               77.10
#
#                        Average Reading Score Passing Math (%)  \
# school_name
# Rodriguez High School                  80.74           66.37%
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
#Create a table that lists the average math Score for students of each grade level (9th, 10th, 11th, 12th) at each school.

#Create for each grade and group by school
school_group_9th = school_data_complete[school_data_complete['grade'] == '9th'].groupby('school_name')
school_group_10th = school_data_complete[school_data_complete['grade'] == '10th'].groupby('school_name')
school_group_11th = school_data_complete[school_data_complete['grade'] == '11th'].groupby('school_name')
school_group_12th = school_data_complete[school_data_complete['grade'] == '12th'].groupby('school_name')

math_scores_grade = pd.DataFrame({
    '9th Grade': school_group_9th['math_score'].mean(),
    '10th Grade': school_group_10th['math_score'].mean(),
    '11th Grade': school_group_11th['math_score'].mean(),
    '12th Grade': school_group_12th['math_score'].mean()},
    )

#Formatting
math_scores_grade = math_scores_grade.applymap("{:.2f}".format)

math_scores_grade
# Out:
#                       9th Grade 10th Grade 11th Grade 12th Grade
# school_name
# Bailey High School        77.08      77.00      77.52      76.49
# Cabrera High School       83.09      83.15      82.77      83.28
# Figueroa High School      76.40      76.54      76.88      77.15
# Ford High School          77.36      77.67      76.92      76.18
# Griffin High School       82.04      84.23      83.84      83.36
# Hernandez High School     77.44      77.34      77.14      77.19
# Holden High School        83.79      83.43      85.00      82.86
# Huang High School         77.03      75.91      76.45      77.23
# Johnson High School       77.19      76.69      77.49      76.86
# Pena High School          83.63      83.37      84.33      84.12
# Rodriguez High School     76.86      76.61      76.40      77.69
# Shelton High School       83.42      82.92      83.38      83.78
# Thomas High School        83.59      83.09      83.50      83.50
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
#Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.

#Create for each grade and group by school
school_group_9th = school_data_complete[school_data_complete['grade'] == '9th'].groupby('school_name')
school_group_10th = school_data_complete[school_data_complete['grade'] == '10th'].groupby('school_name')
school_group_11th = school_data_complete[school_data_complete['grade'] == '11th'].groupby('school_name')
school_group_12th = school_data_complete[school_data_complete['grade'] == '12th'].groupby('school_name')

reading_scores_grade = pd.DataFrame({
    '9th Grade': school_group_9th['reading_score'].mean(),
    '10th Grade': school_group_10th['reading_score'].mean(),
    '11th Grade': school_group_11th['reading_score'].mean(),
    '12th Grade': school_group_12th['reading_score'].mean()},
    )

#Formatting
reading_scores_grade = reading_scores_grade.applymap("{:.2f}".format)

reading_scores_grade
# Out:
#                       9th Grade 10th Grade 11th Grade 12th Grade
# school_name
# Bailey High School        81.30      80.91      80.95      80.91
# Cabrera High School       83.68      84.25      83.79      84.29
# Figueroa High School      81.20      81.41      80.64      81.38
# Ford High School          80.63      81.26      80.40      80.66
# Griffin High School       83.37      83.71      84.29      84.01
# Hernandez High School     80.87      80.66      81.40      80.86
# Holden High School        83.68      83.32      83.82      84.70
# Huang High School         81.29      81.51      81.42      80.31
# Johnson High School       81.26      80.77      80.62      81.23
# Pena High School          83.81      83.61      84.34      84.59
# Rodriguez High School     80.99      80.63      80.86      80.38
# Shelton High School       84.12      83.44      84.37      82.78
# Thomas High School        83.73      84.25      83.59      83.83
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Create 4 bins of average Spending Ranges 
bins = [0, 585, 630, 645, 680]

# Create labels for these bins
group_labels = ["<$585", "$585~630", "$630~645", "$645~680"]

# place the data into bins
school_data_complete['avg_budget'] = school_data_complete['budget'] / school_data_complete['size']
school_data_complete['School Spending'] = pd.cut(school_data_complete["avg_budget"], bins, labels=group_labels)
#school_data_complete.head()

#group data by school spending
group_school_spending = school_data_complete.groupby("School Spending")
#group_school_spending.sum()

#Average Math Score and Average Reading Score
average_math = group_school_spending["math_score"].mean()
#average_math
average_reading = group_school_spending["reading_score"].mean()
#average_reading

#% Passing Math and % Passing Reading and Overall Passing Rate (Average of the above two)
number_pass_math = school_data_complete[school_data_complete['math_score']>=70].groupby('School Spending')['math_score'].count()
number_pass_reading = school_data_complete[school_data_complete['reading_score']>=70].groupby('School Spending')['reading_score'].count()
number_students =  group_school_spending['size'].count()
#number_pass_math

percent_pass_math = number_pass_math /number_students *100
percent_pass_reading = number_pass_reading /number_students *100
#percent_pass_reading
Overall_Passing_Rate = (percent_pass_math + percent_pass_reading) /2
#Overall_Passing_Rate

scores_by_school_spending = pd.DataFrame({
    'Average Math Score': average_math,
    'Average Reading Score': average_reading,
    'Passing Math (%)': percent_pass_math,
    'Passing Reading (%)': percent_pass_reading,
    'Overall Passing Rate (%)': Overall_Passing_Rate}
    )

#Formatting
scores_by_school_spending["Average Math Score"] = scores_by_school_spending["Average Math Score"].astype(float).map("{:.2f}".format)
scores_by_school_spending["Average Reading Score"] = scores_by_school_spending["Average Reading Score"].astype(float).map("${:.2f}".format)
scores_by_school_spending["Passing Math (%)"] = scores_by_school_spending["Passing Math (%)"].map("{:.2f}%".format)
scores_by_school_spending["Passing Reading (%)"] = scores_by_school_spending["Passing Reading (%)"].map("{:.2f}%".format)
scores_by_school_spending["Overall Passing Rate (%)"] = scores_by_school_spending["Overall Passing Rate (%)"].map("{:.2f}%".format)

scores_by_school_spending
# Out:
#                 Average Math Score Average Reading Score Passing Math (%)  \
# School Spending
# <$585                        83.36                $83.96           93.70%
# $585~630                     79.98                $82.31           79.11%
# $630~645                     77.82                $81.30           70.62%
# $645~680                     77.05                $81.01           66.23%
#
#                 Passing Reading (%) Overall Passing Rate (%)
# School Spending
# <$585                        96.69%                   95.19%
# $585~630                     88.51%                   83.81%
# $630~645                     82.60%                   76.61%
# $645~680                     81.11%                   73.67%

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Create 4 bins of school size 
bins = [0, 1000, 2000, 5000]

# Create labels for these bins
group_labels = ["<1000", "1000~2000", "2000~5000"]

# place the data into bins
school_data_complete['School Size'] = pd.cut(school_data_complete["size"], bins, labels=group_labels)
#school_data_complete.head()

#group data by school size 
group_school_size = school_data_complete.groupby("School Size")
group_school_size.sum()

#Average Math Score and Average Reading Score
average_math = group_school_size["math_score"].mean()
#average_math
average_reading = group_school_size["reading_score"].mean()
#average_reading

#% Passing Math and % Passing Reading and Overall Passing Rate (Average of the above two)
number_pass_math = school_data_complete[school_data_complete['math_score']>=70].groupby('School Size')['math_score'].count()
number_pass_reading = school_data_complete[school_data_complete['reading_score']>=70].groupby('School Size')['reading_score'].count()
number_students =  group_school_size['size'].count()
#number_pass_math

percent_pass_math = number_pass_math /number_students *100
percent_pass_reading = number_pass_reading /number_students *100
percent_pass_reading
Overall_Passing_Rate = (percent_pass_math + percent_pass_reading) /2
Overall_Passing_Rate

scores_by_school_spending = pd.DataFrame({
    'Average Math Score': average_math,
    'Average Reading Score': average_reading,
    'Passing Math (%)': percent_pass_math,
    'Passing Reading (%)': percent_pass_reading,
    'Overall Passing Rate (%)': Overall_Passing_Rate}
    )

#Formatting
group_school_size["Average Math Score"] = group_school_size["Average Math Score"].astype(float).map("{:.2f}".format)
group_school_size["Average Reading Score"] = group_school_size["Average Reading Score"].astype(float).map("${:.2f}".format)
group_school_size["Passing Math (%)"] = group_school_size["Passing Math (%)"].map("{:.2f}%".format)
group_school_size["Passing Reading (%)"] = group_school_size["Passing Reading (%)"].map("{:.2f}%".format)
group_school_size["Overall Passing Rate (%)"] = group_school_size["Overall Passing Rate (%)"].map("{:.2f}%".format)

#scores_by_school_spending
# Out:
# School Size
# <1000        94.996400
# 1000~2000    95.194790
# 2000~5000    75.388769
# dtype: float64

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              96.586489          90.432244
# District             80.799062          53.672208
